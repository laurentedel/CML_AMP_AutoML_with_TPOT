# %% [markdown]
# # AutoML with FLAML
#
# Automated machine learning holds much promise as an assistive tool for practitioners working with data. In this notebook, we demonstrate the [FLAML](https://github.com/microsoft/FLAML) library for AutoML. FLAML is a fast and lightweight AutoML library that finds accurate machine learning models efficiently.
#
# We'll work with a small sample of the [credit card fraud dataset](https://www.kaggle.com/mlg-ulb/creditcardfraud). We'll first load the data and perform some automated data profiling. Then, we will use FLAML to automatically train and tune a classifier to detect fraud, optimizing for Average Precision due to the class imbalance.

# %% [markdown]
# ## Setup
#
# We import all dependencies up front.
# **Note:** Ensure you have installed FLAML in your environment (`pip install flaml`).

# %%
import mlflow
import mlflow.sklearn
mlflow.set_experiment("fraud_detection_flaml_v3")
# Out:
# 2026/01/28 05:46:44 INFO mlflow.tracking.fluent: Experiment with name 'fraud_detection_flaml_v3' does not exist. Creating a new experiment.
# <Experiment: artifact_location='/home/cdsw/.experiments/c8ye-hfco-331k-oxps', creation_time=None, experiment_id='c8ye-hfco-331k-oxps', last_update_time=None, lifecycle_stage='active', name='fraud_detection_flaml_v3', tags={}>

# %%
import pydantic
import pydantic_core

print(f"Pydantic version: {pydantic.VERSION}")
print(f"Pydantic Core version: {pydantic_core.__version__}")
# Out:
# Pydantic version: 2.12.5
# Pydantic Core version: 2.41.5

# %%
import os
import time
import pickle
import pandas as pd

# FLAML Import
from flaml import AutoML

from ydata_profiling import ProfileReport
from sklearn.model_selection import train_test_split
from sklearn.metrics import average_precision_score

# %% [markdown]
# ### Load and profile the data

# %%
transactions = pd.read_csv("data/creditcardsample.csv")

# %% [markdown]
# Let's profile the data. Exploratory data analysis is not a mechanical process, and thus impossible to automate completely. However, open source provides us several options to automatically generate common charts. Here, we're using [pandas-profiling](https://github.com/pandas-profiling/pandas-profiling) to view histograms of each variable and detect duplicate entries.

# %%
ProfileReport(transactions, interactions=None)
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/31 [00:00<?, ?it/s]
# 100%|██████████| 31/31 [00:00<00:00, 52.34it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;meta charset=utf-8&gt;&lt;meta content=&quot;width=device-width,initial-scale=1,shrink-to-fit=no&quot; name=viewport&gt;&lt;meta content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot; name=description&gt;&lt;meta content=&quot;YData and the open source community.&quot; name=author&gt;&lt;meta content=&quot;YData Profiling vv4.17.0&quot; name=generator&gt;&lt;meta content=https://github.com/ydataai/ydata-profiling name=url&gt;&lt;meta content=&quot;2026-01-28 10:47:00.132966&quot; name=date&gt;&lt;title&gt;YData Profiling Report&lt;/title&gt;&lt;style&gt;@charset &quot;UTF-8&quot;;/*!
#  * Bootstrap  v5.3.3 (https://getbootstrap.com/)
#  * Copyright 2011-2024 The Bootstrap Authors
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/main/LICENSE)
#  */:root,[data-bs-theme=light]{--bs-blue:#0d6efd;--bs-indigo:#6610f2;--bs-purple:#6f42c1;--bs-pink:#d63384;--bs-red:#dc3545;--bs-orange:#fd7e14;--bs-yellow:#ffc107;--bs-green:#198754;--bs-teal:#20c997;--bs-cyan:#0dcaf0;--bs-black:#000;--bs-white:#fff;--bs-gray:#6c757d;--bs-gray-dark:#343a40;--bs-gray-100:#f8f9fa;--bs-gray-200:#e9ecef;--bs-gray-300:#dee2e6;--bs-gray-400:#ced4da;--bs-gray-500:#adb5bd;--bs-gray-600:#6c757d;--bs-gray-700:#495057;--bs-gray-800:#343a40;--bs-gray-900:#212529;--bs-primary:#0d6efd;--bs-secondary:#6c757d;--bs-success:#198754;--bs-info:#0dcaf0;--bs-warning:#ffc107;--bs-danger:#dc3545;--bs-light:#f8f9fa;--bs-dark:#212529;--bs-primary-rgb:13,110,253;--bs-secondary-rgb:108,117,125;--bs-success-rgb:25,135,84;--bs-info-rgb:13,202,240;--bs-warning-rgb:255,193,7;--bs-danger-rgb:220,53,69;--bs-light-rgb:248,249,250;--bs-dark-rgb:33,37,41;--bs-primary-text-emphasis:#052c65;--bs-secondary-text-emphasis:#2b2f32;--bs-success-text-emphasis:#0a3622;--bs-info-text-emphasis:#055160;--bs-warning-text-emphasis:#664d03;--bs-danger-text-emphasis:#58151c;--bs-light-text-emphasis:#495057;--bs-dark-text-emphasis:#495057;--bs-primary-bg-subtle:#cfe2ff;--bs-secondary-bg-subtle:#e2e3e5;--bs-success-bg-subtle:#d1e7dd;--bs-info-bg-subtle:#cff4fc;--bs-warning-bg-subtle:#fff3cd;--bs-danger-bg-subtle:#f8d7da;--bs-light-bg-subtle:#fcfcfd;--bs-dark-bg-subtle:#ced4da;--bs-primary-border-subtle:#9ec5fe;--bs-secondary-border-subtle:#c4c8cb;--bs-success-border-subtle:#a3cfbb;--bs-info-border-subtle:#9eeaf9;--bs-warning-border-subtle:#ffe69c;--bs-danger-border-subtle:#f1aeb5;--bs-light-border-subtle:#e9ecef;--bs-dark-border-subtle:#adb5bd;--bs-white-rgb:255,255,255;--bs-black-rgb:0,0,0;--bs-font-sans-serif:system-ui,-apple-system,&quot;Segoe UI&quot;,Roboto,&quot;Helvetica Neue&quot;,&quot;Noto Sans&quot;,&quot;Liberation Sans&quot;,Arial,sans-serif,&quot;Apple Color Emoji&quot;,&quot;Segoe UI Emoji&quot;,&quot;Segoe UI Symbol&quot;,&quot;Noto Color Emoji&quot;;--bs-font-monospace:SFMono-Regular,Menlo,Monaco,Consolas,&quot;Liberation Mono&quot;,&quot;Courier New&quot;,monospace;--bs-gradient:linear-gradient(180deg, rgba(255, 255, 255, 0.15), rgba(255, 255, 255, 0));--bs-body-font-family:var(--bs-font-sans-serif);--bs-body-font-size:1rem;--bs-body-font-weight:400;--bs-body-line-height:1.5;--bs-body-color:#212529;--bs-body-color-rgb:33,37,41;--bs-body-bg:#fff;--bs-body-bg-rgb:255,255,255;--bs-emphasis-color:#000;--bs-emphasis-color-rgb:0,0,0;--bs-secondary-color:rgba(33, 37, 41, 0.75);--bs-secondary-color-rgb:33,37,41;--bs-secondary-bg:#e9ecef;--bs-secondary-bg-rgb:233,236,239;--bs-tertiary-color:rgba(33, 37, 41, 0.5);--bs-tertiary-color-rgb:33,37,41;--bs-tertiary-bg:#f8f9fa;--bs-tertiary-bg-rgb:248,249,250;--bs-heading-color:inherit;--bs-link-color:#0d6efd;--bs-link-color-rgb:13,110,253;--bs-link-decoration:underline;--bs-link-hover-color:#0a58ca;--bs-link-hover-color-rgb:10,88,202;--bs-code-color:#d63384;--bs-highlight-color:#212529;--bs-highlight-bg:#fff3cd;--bs-border-width:1px;--bs-border-style:solid;--bs-border-color:#dee2e6;--bs-border-color-translucent:rgba(0, 0, 0, 0.175);--bs-border-radius:0.375rem;--bs-border-radius-sm:0.25rem;--bs-border-radius-lg:0.5rem;--bs-border-radius-xl:1rem;--bs-border-radius-xxl:2rem;--bs-border-radius-2xl:var(--bs-border-radius-xxl);--bs-border-radius-pill:50rem;--bs-box-shadow:0 0.5rem 1rem rgba(0, 0, 0, 0.15);--bs-box-shadow-sm:0 0.125rem 0.25rem rgba(0, 0, 0, 0.075);--bs-box-shadow-lg:0 1rem 3rem rgba(0, 0, 0, 0.175);--bs-box-shadow-inset:inset 0 1px 2px rgba(0, 0, 0, 0.075);--bs-focus-ring-width:0.25rem;--bs-focus-ring-opacity:0.25;--bs-focus-ring-color:rgba(13, 110, 253, 0.25);--bs-form-valid-color:#198754;--bs-form-valid-border-color:#198754;--bs-form-invalid-color:#dc3545;--bs-form-invalid-border-color:#dc3545}[data-bs-theme=dark]{color-scheme:dark;--bs-body-color:#dee2e6;--bs-body-color-rgb:222,226,230;--bs-body-bg:#212529;--bs-body-bg-rgb:33,37,41;--bs-emphasis-color:#fff;--bs-emphasis-color-rgb:2 ...

# %% [markdown]
# There are no missing values, but there are some duplicate rows. We don't want to accidentally polute our test set with rows that are duplicated in the training set, so we'll drop them.

# %%
unique_transactions = transactions.drop_duplicates()

# %%
X = unique_transactions.drop(["Class", "Time"], axis="columns")
y = unique_transactions.Class

# %% [markdown]
# Split our data into train and test sets, so we can evaluate performance on a hold out set.

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, shuffle=True, stratify=y)

# %% [markdown]
# ## Fit a model with FLAML
#
# We define the `AutoML` settings below.
#
# We set `time_budget` to 300 seconds (5 minutes). FLAML will try different algorithms (XGBoost, LightGBM, Random Forest, etc.) and hyperparameter configurations within this time limit.
#
# We use `metric='ap'` (Average Precision) to handle the class imbalance, similar to the original TPOT configuration.

# %%
# Initialize the AutoML instance
automl = AutoML()

# Define settings
automl_settings = {
    "time_budget": 30,  # Total time limit in seconds
    "metric": 'ap',      # Average Precision (good for imbalanced fraud data)
    "task": 'classification',
    "log_file_name": 'flaml.log',
    "seed": 42,
    "n_jobs": -1,        # Use all available CPU cores
}

print(f"Starting AutoML with a time budget of {automl_settings['time_budget']} seconds...")

# Fit the model
with mlflow.start_run(run_name="flaml_run_v1"):
# Run FLAML as usual
    print("Starting FLAML training...")
    automl.fit(X_train=X_train, y_train=y_train, **automl_settings)
    
    # 3. Log the Best Results
    print(f"Best ML leaner: {automl.best_estimator}")
    print(f"Best loss: {automl.best_loss}")
    
    # Log best hyperparameters (config)
    mlflow.log_params(automl.best_config)
    
    # Log the best metric found (Note: FLAML minimizes loss, so 1-loss is often the score)
    mlflow.log_metric("best_loss", automl.best_loss)
    mlflow.log_metric("best_ap_score", 1 - automl.best_loss) # formatted for Average Precision
    
    # Log the name of the best estimator (e.g., 'xgboost', 'lgbm')
    mlflow.log_param("best_estimator", automl.best_estimator)

    # 4. Log the Detailed History File
    # FLAML writes a log file (set in your settings as 'flaml.log')
    # We log this as an artifact so you can download/inspect the full trial history later
    mlflow.log_artifact("flaml.log")
    
    # 5. Log the Final Model
    # This saves the model in a format MLflow can serve or deploy later
    best_model = automl.model.estimator
    #mlflow.sklearn.log_model(best_model, "model")
    mlflow.sklearn.log_model(
    sk_model=best_model, 
    artifact_path="model", 
    input_example=X_train.head(1)
)

    # FLAML stores the best found model pipeline in 'model.estimator'
    #best_model = automl.model.estimator
    #mlflow.sklearn.log_model(best_model, "model",input_example=X_train.head(1))

    print("Run saved to MLflow!")
# Out:
# Starting AutoML with a time budget of 30 seconds...
# Starting FLAML training...
# [flaml.automl.logger: 01-28 05:47:37] {1752} INFO - task = classification
# [flaml.automl.logger: 01-28 05:47:37] {1763} INFO - Evaluation method: holdout
# [flaml.automl.logger: 01-28 05:47:37] {1862} INFO - Minimizing error metric: 1-ap
# [flaml.automl.logger: 01-28 05:47:37] {1979} INFO - List of ML learners in AutoML Run: ['lgbm', 'rf', 'xgboost', 'extra_tree', 'xgb_limitdepth', 'sgd', 'lrl1']
# [flaml.automl.logger: 01-28 05:47:37] {2282} INFO - iteration 0, current learner lgbm
# [flaml.automl.logger: 01-28 05:47:37] {2417} INFO - Estimated sufficient time budget=224s. Estimated necessary time budget=5s.
# [flaml.automl.logger: 01-28 05:47:38] {2466} INFO -  at 0.2s,	estimator lgbm's best error=0.1679,	best estimator lgbm's best error=0.1679
# [flaml.automl.logger: 01-28 05:47:38] {2282} INFO - iteration 1, current learner lgbm
# [flaml.automl.logger: 01-28 05:47:38] {2466} INFO -  at 0.4s,	estimator lgbm's best error=0.1613,	best estimator lgbm's best error=0.1613
# [flaml.automl.logger: 01-28 05:47:38] {2282} INFO - iteration 2, current learner sgd
# [flaml.automl.logger: 01-28 05:47:38] {2466} INFO -  at 0.6s,	estimator sgd's best error=0.3954,	best estimator lgbm's best error=0.1613
# [flaml.automl.logger: 01-28 05:47:38] {2282} INFO - iteration 3, current learner sgd
# [flaml.automl.logger: 01-28 05:47:38] {2466} INFO -  at 0.8s,	estimator sgd's best error=0.3954,	best estimator lgbm's best error=0.1613
# [flaml.automl.logger: 01-28 05:47:38] {2282} INFO - iteration 4, current learner lgbm
# [flaml.automl.logger: 01-28 05:47:38] {2466} INFO -  at 0.9s,	estimator lgbm's best error=0.1569,	best estimator lgbm's best error=0.1569
# [flaml.automl.logger: 01-28 05:47:38] {2282} INFO - iteration 5, current learner lgbm
# [flaml.automl.logger: 01-28 05:47:38] {2466} INFO -  at 1.1s,	estimator lgbm's best error=0.1291,	best estimator lgbm's best error=0.1291
# [flaml.automl.logger: 01-28 05:47:38] {2282} INFO - iteration 6, current learner lgbm
# [flaml.automl.logger: 01-28 05:47:38] {2466} INFO -  at 1.2s,	estimator lgbm's best error=0.0940,	best estimator lgbm's best error=0.0940
# [flaml.automl.logger: 01-28 05:47:38] {2282} INFO - iteration 7, current learner lgbm
# [flaml.automl.logger: 01-28 05:47:39] {2466} INFO -  at 1.4s,	estimator lgbm's best error=0.0940,	best estimator lgbm's best error=0.0940
# [flaml.automl.logger: 01-28 05:47:39] {2282} INFO - iteration 8, current learner lgbm
# [flaml.automl.logger: 01-28 05:47:39] {2466} INFO -  at 1.5s,	estimator lgbm's best error=0.0940,	best estimator lgbm's best error=0.0940
# [flaml.automl.logger: 01-28 05:47:39] {2282} INFO - iteration 9, current learner xgboost
# [flaml.automl.logger: 01-28 05:47:39] {2466} INFO -  at 1.7s,	estimator xgboost's best error=0.2221,	best estimator lgbm's best error=0.0940
# [flaml.automl.logger: 01-28 05:47:39] {2282} INFO - iteration 10, current learner extra_tree
# [flaml.automl.logger: 01-28 05:47:39] {2466} INFO -  at 1.9s,	estimator extra_tree's best error=0.3640,	best estimator lgbm's best error=0.0940
# [flaml.automl.logger: 01-28 05:47:39] {2282} INFO - iteration 11, current learner rf
# [flaml.automl.logger: 01-28 05:47:39] {2466} INFO -  at 2.0s,	estimator rf's best error=0.2769,	best estimator lgbm's best error=0.0940
# [flaml.automl.logger: 01-28 05:47:39] {2282} INFO - iteration 12, current learner rf
# [flaml.automl.logger: 01-28 05:47:40] {2466} INFO -  at 2.3s,	estimator rf's best error=0.1965,	best estimator lgbm's best error=0.0940
# [flaml.automl.logger: 01-28 05:47:40] {2282} INFO - iteration 13, current learner xgboost
# [flaml.automl.logger: 01-28 05:47:40] {2466} INFO -  at 2.4s,	estimator xgboost's best error=0.1826,	best estimator lgbm's best error=0.0940
# [flaml.automl.logger: 01-28 05:47:40] {2282} INFO - iteration 14, current learner xgboost
# [flaml.automl.logger: 01-28 05:47:40] {2466} INFO -  at 2.5s,	estimator xgboost's best error=0.1559,	best estimator lgbm's best error=0.0940
# [flaml.automl.logger: 01-28 05:47:40] {2282} INFO - iteration 15, current learner rf
# [flaml.automl.logger: 01-28 05:47:40] {2466} INFO -  at 2.7s,	estimator rf's best error=0.1835,	best estimator lgbm's best error=0.0940
# [flaml.automl.logger: 01-28 05:47:40] {2282} INFO - iteration 16, current learner extra_tree
# [flaml.automl.logger: 01-28 05:47:40] {2466} INFO -  at 2.9s,	estimator extra_tree's best error=0.3500,	best estimator lgbm's best error=0.0940
# [flaml.automl.logger: 01-28 05:47:40] {2282} INFO - iteration 17, current learner lgbm
# [flaml.automl.logger: 01-28 05:47:40] {2466} INFO -  at 3.0s,	estimator lgbm's best error=0.0940,	best estimator lgbm's best error=0.0940
# [flaml.automl.logger: 01-28 05:47:40] {2282} INFO - iteration 18, current learner sgd
# [flaml.automl.logger: 01-28 05:47:41] {2466} INFO -  at 3.2s,	estimator sgd's best error=0.1641,	best estimator lgbm's best error=0.0940
# [flaml.automl.logger: 01-28 05:47:41] {2282} INFO - iteration 19, current learner lgbm
# [flaml.automl.logger: 01-28 05:47:41] {2466} INFO -  at 3.4s,	estimator lgbm's best error=0.0940,	best estimator lgbm's best error=0.0940
# [flaml.automl.logger: 01-28 05:47:41] {2282} INFO - iteration 20, current learner extra_tree
# [flaml.automl.logger: 01-28 05:47:41] {2466} INFO -  at 3.6s,	estimator extra_tree's best error=0.2766,	best estimator lgbm's best error=0.0940
# [flaml.automl.logger: 01-28 05:47:41] {2282} INFO - iteration 21, current learner xgboost
# [flaml.automl.logger: 01-28 05:47:41] {2466} INFO -  at 3.7s,	estimator xgboost's best error=0.1559,	best estimator lgbm's best error=0.0940
# [flaml.automl.logger: 01-28 05:47:41] {2282} INFO - iteration 22, current learner extra_tree
# [flaml.automl.logger: 01-28 05:47:41] {2466} INFO -  at 3.9s,	estimator extra_tree's best error=0.1443,	best estimator lgbm's best error=0.0940
# [flaml.automl.logger: 01-28 05:47:41] {2282} INFO - iteration 23, current learner lgbm
# [flaml.automl.logger: 01-28 05:47:41] {2466} INFO -  at 4.0s,	estimator lgbm's best error=0.0940,	best estimator lgbm's best error=0.0940
# [flaml.automl.logger: 01-28 05:47:41] {2282} INFO - iteration 24, current learner rf
# [flaml.automl.logger: 01-28 05:47:41] {2466} INFO -  at 4.2s,	estimator rf's best error=0.1080,	best estimator lgbm's best error=0.0940
# [flaml.automl.logger: 01-28 05:47:41] {2282} INFO - iteration 25, current learner extra_tree
# [flaml.automl.logger: 01-28 05:47:42] {2466} INFO -  at 4.4s,	estimator extra_tree's best error=0.1443,	best estimator lgbm's best error=0.0940
# [flaml.automl.logger: 01-28 05:47:42] {2282} INFO - iteration 26, current learner sgd
# [flaml.automl.logger: 01-28 05:47:42] {2466} INFO -  at 4.6s,	estimator sgd's best error=0.1641,	best estimator lgbm's best error=0.0940
# [flaml.automl.logger: 01-28 05:47:42] {2282} INFO - iteration 27, current learner rf
# [flaml.automl.logger: 01-28 05:47:42] {2466} INFO -  at 4.7s,	estimator rf's best error=0.1080,	best estimator lgbm's best error=0.0940
# [flaml.automl.logger: 01-28 05:47:42] {2282} INFO - iteration 28, current learner extra_tree
# [flaml.automl.logger: 01-28 05:47:42] {2466} INFO -  at 4.9s,	estimator extra_tree's best error=0.1443,	best estimator lgbm's best error=0.0940
# [flaml.automl.logger: 01-28 05:47:42] {2282} INFO - iteration 29, current learner sgd
# [flaml.automl.logger: 01-28 05:47:42] {2466} INFO -  at 5.1s,	estimator sgd's best error=0.1641,	best estimator lgbm's best error=0.0940
# [flaml.automl.logger: 01-28 05:47:42] {2282} INFO - iteration 30, current learner sgd
# [flaml.automl.logger: 01-28 05:47:43] {2466} INFO -  at 5.3s,	estimator sgd's best error=0.1641,	best estimator lgbm's best error=0.0940
# [flaml.automl.logger: 01-28 05:47:43] {2282} INFO - iteration 31, current learner lgbm
# [flaml.automl.logger: 01-28 05:47:43] {2466} INFO -  at 5.5s,	estimator lgbm's best error=0.0907,	best estimator lgbm's best error=0.0907
# [flaml.automl.logger: 01-28 05:47:43] {2282} INFO - iteration 32, current learner lgbm
# [flaml.automl.logger: 01-28 05:47:43] {2466} INFO -  at 5.6s,	estimator lgbm's best error=0.0907,	best estimator lgbm's best error=0.0907
# [flaml.automl.logger: 01-28 05:47:43] {2282} INFO - iteration 33, current learner rf
# [flaml.automl.logger: 01-28 05:47:43] {2466} INFO -  at 5.8s,	estimator rf's best error=0.1080,	best estimator lgbm's best error=0.0907
# [flaml.automl.logger: 01-28 05:47:43] {2282} INFO - iteration 34, current learner sgd
# [flaml.automl.logger: 01-28 05:47:43] {2466} INFO -  at 6.0s,	estimator sgd's best error=0.1641,	best estimator lgbm's best error=0.0907
# [flaml.automl.logger: 01-28 05:47:43] {2282} INFO - iteration 35, current learner lgbm
# [flaml.automl.logger: 01-28 05:47:43] {2466} INFO -  at 6.2s,	estimator lgbm's best error=0.0907,	best estimator lgbm's best error=0.0907
# [flaml.automl.logger: 01-28 05:47:43] {2282} INFO - iteration 36, current learner rf
# [flaml.automl.logger: 01-28 05:47:44] {2466} INFO -  at 6.3s,	estimator rf's best error=0.1080,	best estimator lgbm's best error=0.0907
# [flaml.automl.logger: 01-28 05:47:44] {2282} INFO - iteration 37, current learner sgd
# [flaml.automl.logger: 01-28 05:47:44] {2466} INFO -  at 6.5s,	estimator sgd's best error=0.1641,	best estimator lgbm's best error=0.0907
# [flaml.automl.logger: 01-28 05:47:44] {2282} INFO - iteration 38, current learner xgboost
# [flaml.automl.logger: 01-28 05:47:44] {2466} INFO -  at 6.7s,	estimator xgboost's best error=0.1141,	best estimator lgbm's best error=0.0907
# [flaml.automl.logger: 01-28 05:47:44] {2282} INFO - iteration 39, current learner extra_tree
# [flaml.automl.logger: 01-28 05:47:44] {2466} INFO -  at 6.9s,	estimator extra_tree's best error=0.1443,	best estimator lgbm's best error=0.0907
# [flaml.automl.logger: 01-28 05:47:44] {2282} INFO - iteration 40, current learner rf
# [flaml.automl.logger: 01-28 05:47:44] {2466} INFO -  at 7.0s,	estimator rf's best error=0.1080,	best estimator lgbm's best error=0.0907
# [flaml.automl.logger: 01-28 05:47:44] {2282} INFO - iteration 41, current learner xgboost
# [flaml.automl.logger: 01-28 05:47:45] {2466} INFO -  at 7.2s,	estimator xgboost's best error=0.1141,	best estimator lgbm's best error=0.0907
# [flaml.automl.logger: 01-28 05:47:45] {2282} INFO - iteration 42, current learner extra_tree
# [flaml.automl.logger: 01-28 05:47:45] {2466} INFO -  at 7.4s,	estimator extra_tree's best error=0.1443,	best estimator lgbm's best error=0.0907
# [flaml.automl.logger: 01-28 05:47:45] {2282} INFO - iteration 43, current learner lgbm
# [flaml.automl.logger: 01-28 05:47:45] {2466} INFO -  at 7.6s,	estimator lgbm's best error=0.0802,	best estimator lgbm's best error=0.0802
# [flaml.automl.logger: 01-28 05:47:45] {2282} INFO - iteration 44, current learner extra_tree
# [flaml.automl.logger: 01-28 05:47:45] {2466} INFO -  at 7.8s,	estimator extra_tree's best error=0.1396,	best estimator lgbm's best error=0.0802
# [flaml.automl.logger: 01-28 05:47:45] {2282} INFO - iteration 45, current learner sgd
# [flaml.automl.logger: 01-28 05:47:45] {2466} INFO -  at 8.0s,	estimator sgd's best error=0.1641,	best estimator lgbm's best error=0.0802
# [flaml.automl.logger: 01-28 05:47:45] {2282} INFO - iteration 46, current learner xgboost
# [flaml.automl.logger: 01-28 05:47:45] {2466} INFO -  at 8.1s,	estimator xgboost's best error=0.0885,	best estimator lgbm's best error=0.0802
# [flaml.automl.logger: 01-28 05:47:45] {2282} INFO - iteration 47, current learner lgbm
# [flaml.automl.logger: 01-28 05:47:46] {2466} INFO -  at 8.3s,	estimator lgbm's best error=0.0802,	best estimator lgbm's best error=0.0802
# [flaml.automl.logger: 01-28 05:47:46] {2282} INFO - iteration 48, current learner xgboost
# [flaml.automl.logger: 01-28 05:47:46] {2466} INFO -  at 8.5s,	estimator xgboost's best error=0.0885,	best estimator lgbm's best error=0.0802
# [flaml.automl.logger: 01-28 05:47:46] {2282} INFO - iteration 49, current learner lgbm
# [flaml.automl.logger: 01-28 05:47:46] {2466} INFO -  at 8.7s,	estimator lgbm's best error=0.0782,	best estimator lgbm's best error=0.0782
# [flaml.automl.logger: 01-28 05:47:46] {2282} INFO - iteration 50, current learner rf
# [flaml.automl.logger: 01-28 05:47:46] {2466} INFO -  at 9.0s,	estimator rf's best error=0.1080,	best estimator lgbm's best error=0.0782
# [flaml.automl.logger: 01-28 05:47:46] {2282} INFO - iteration 51, current learner sgd
# [flaml.automl.logger: 01-28 05:47:46] {2466} INFO -  at 9.1s,	estimator sgd's best error=0.1641,	best estimator lgbm's best error=0.0782
# [flaml.automl.logger: 01-28 05:47:46] {2282} INFO - iteration 52, current learner lgbm
# [flaml.automl.logger: 01-28 05:47:47] {2466} INFO -  at 9.3s,	estimator lgbm's best error=0.0782,	best estimator lgbm's best error=0.0782
# [flaml.automl.logger: 01-28 05:47:47] {2282} INFO - iteration 53, current learner lgbm
# [flaml.automl.logger: 01-28 05:47:47] {2466} INFO -  at 9.5s,	estimator lgbm's best error=0.0782,	best estimator lgbm's best error=0.0782
# [flaml.automl.logger: 01-28 05:47:47] {2282} INFO - iteration 54, current learner lgbm
# [flaml.automl.logger: 01-28 05:47:47] {2466} INFO -  at 9.7s,	estimator lgbm's best error=0.0779,	best estimator lgbm's best error=0.0779
# [flaml.automl.logger: 01-28 05:47:47] {2282} INFO - iteration 55, current learner lgbm
# [flaml.automl.logger: 01-28 05:47:47] {2466} INFO -  at 9.9s,	estimator lgbm's best error=0.0779,	best estimator lgbm's best error=0.0779
# [flaml.automl.logger: 01-28 05:47:47] {2282} INFO - iteration 56, current learner xgboost
# [flaml.automl.logger: 01-28 05:47:47] {2466} INFO -  at 10.0s,	estimator xgboost's best error=0.0885,	best estimator lgbm's best error=0.0779
# [flaml.automl.logger: 01-28 05:47:47] {2282} INFO - iteration 57, current learner lgbm
# [flaml.automl.logger: 01-28 05:47:48] {2466} INFO -  at 10.3s,	estimator lgbm's best error=0.0779,	best estimator lgbm's best error=0.0779
# [flaml.automl.logger: 01-28 05:47:48] {2282} INFO - iteration 58, current learner lgbm
# [flaml.automl.logger: 01-28 05:47:48] {2466} INFO -  at 10.5s,	estimator lgbm's best error=0.0779,	best estimator lgbm's best error=0.0779
# [flaml.automl.logger: 01-28 05:47:48] {2282} INFO - iteration 59, current learner xgboost
# [flaml.automl.logger: 01-28 05:47:48] {2466} INFO -  at 10.7s,	estimator xgboost's best error=0.0885,	best estimator lgbm's best error=0.0779
# [flaml.automl.logger: 01-28 05:47:48] {2282} INFO - iteration 60, current learner lgbm
# [flaml.automl.logger: 01-28 05:47:48] {2466} INFO -  at 10.8s,	estimator lgbm's best error=0.0779,	best estimator lgbm's best error=0.0779
# [flaml.automl.logger: 01-28 05:47:48] {2282} INFO - iteration 61, current learner xgboost
# [flaml.automl.logger: 01-28 05:47:48] {2466} INFO -  at 11.0s,	estimator xgboost's best error=0.0774,	best estimator xgboost's best error=0.0774
# [flaml.automl.logger: 01-28 05:47:48] {2282} INFO - iteration 62, current learner rf
# [flaml.automl.logger: 01-28 05:47:48] {2466} INFO -  at 11.2s,	estimator rf's best error=0.1080,	best estimator xgboost's best error=0.0774
# [flaml.automl.logger: 01-28 05:47:48] {2282} INFO - iteration 63, current learner xgboost
# [flaml.automl.logger: 01-28 05:47:49] {2466} INFO -  at 11.4s,	estimator xgboost's best error=0.0774,	best estimator xgboost's best error=0.0774
# [flaml.automl.logger: 01-28 05:47:49] {2282} INFO - iteration 64, current learner xgboost
# [flaml.automl.logger: 01-28 05:47:49] {2466} INFO -  at 11.6s,	estimator xgboost's best error=0.0653,	best estimator xgboost's best error=0.0653
# [flaml.automl.logger: 01-28 05:47:49] {2282} INFO - iteration 65, current learner rf
# [flaml.automl.logger: 01-28 05:47:49] {2466} INFO -  at 11.8s,	estimator rf's best error=0.1080,	best estimator xgboost's best error=0.0653
# [flaml.automl.logger: 01-28 05:47:49] {2282} INFO - iteration 66, current learner xgboost
# [flaml.automl.logger: 01-28 05:47:49] {2466} INFO -  at 12.0s,	estimator xgboost's best error=0.0653,	best estimator xgboost's best error=0.0653
# [flaml.automl.logger: 01-28 05:47:49] {2282} INFO - iteration 67, current learner xgboost
# [flaml.automl.logger: 01-28 05:47:50] {2466} INFO -  at 12.5s,	estimator xgboost's best error=0.0653,	best estimator xgboost's best error=0.0653
# [flaml.automl.logger: 01-28 05:47:50] {2282} INFO - iteration 68, current learner xgboost
# [flaml.automl.logger: 01-28 05:47:50] {2466} INFO -  at 12.7s,	estimator xgboost's best error=0.0653,	best estimator xgboost's best error=0.0653
# [flaml.automl.logger: 01-28 05:47:50] {2282} INFO - iteration 69, current learner rf
# [flaml.automl.logger: 01-28 05:47:50] {2466} INFO -  at 12.9s,	estimator rf's best error=0.1073,	best estimator xgboost's best error=0.0653
# [flaml.automl.logger: 01-28 05:47:50] {2282} INFO - iteration 70, current learner sgd
# [flaml.automl.logger: 01-28 05:47:50] {2466} INFO -  at 13.1s,	estimator sgd's best error=0.1641,	best estimator xgboost's best error=0.0653
# [flaml.automl.logger: 01-28 05:47:50] {2282} INFO - iteration 71, current learner sgd
# [flaml.automl.logger: 01-28 05:47:50] {2466} INFO -  at 13.2s,	estimator sgd's best error=0.1641,	best estimator xgboost's best error=0.0653
# [flaml.automl.logger: 01-28 05:47:50] {2282} INFO - iteration 72, current learner xgboost
# [flaml.automl.logger: 01-28 05:47:51] {2466} INFO -  at 13.5s,	estimator xgboost's best error=0.0653,	best estimator xgboost's best error=0.0653
# [flaml.automl.logger: 01-28 05:47:51] {2282} INFO - iteration 73, current learner sgd
# [flaml.automl.logger: 01-28 05:47:51] {2466} INFO -  at 13.7s,	estimator sgd's best error=0.1641,	best estimator xgboost's best error=0.0653
# [flaml.automl.logger: 01-28 05:47:51] {2282} INFO - iteration 74, current learner sgd
# [flaml.automl.logger: 01-28 05:47:51] {2466} INFO -  at 13.9s,	estimator sgd's best error=0.1641,	best estimator xgboost's best error=0.0653
# [flaml.automl.logger: 01-28 05:47:51] {2282} INFO - iteration 75, current learner sgd
# [flaml.automl.logger: 01-28 05:47:51] {2466} INFO -  at 14.0s,	estimator sgd's best error=0.1641,	best estimator xgboost's best error=0.0653
# [flaml.automl.logger: 01-28 05:47:51] {2282} INFO - iteration 76, current learner xgboost
# [flaml.automl.logger: 01-28 05:47:52] {2466} INFO -  at 14.6s,	estimator xgboost's best error=0.0653,	best estimator xgboost's best error=0.0653
# [flaml.automl.logger: 01-28 05:47:52] {2282} INFO - iteration 77, current learner xgboost
# [flaml.automl.logger: 01-28 05:47:52] {2466} INFO -  at 14.8s,	estimator xgboost's best error=0.0653,	best estimator xgboost's best error=0.0653
# [flaml.automl.logger: 01-28 05:47:52] {2282} INFO - iteration 78, current learner sgd
# [flaml.automl.logger: 01-28 05:47:52] {2466} INFO -  at 14.9s,	estimator sgd's best error=0.1641,	best estimator xgboost's best error=0.0653
# [flaml.automl.logger: 01-28 05:47:52] {2282} INFO - iteration 79, current learner xgboost
# [flaml.automl.logger: 01-28 05:47:52] {2466} INFO -  at 15.2s,	estimator xgboost's best error=0.0653,	best estimator xgboost's best error=0.0653
# [flaml.automl.logger: 01-28 05:47:52] {2282} INFO - iteration 80, current learner xgboost
# [flaml.automl.logger: 01-28 05:47:53] {2466} INFO -  at 15.4s,	estimator xgboost's best error=0.0653,	best estimator xgboost's best error=0.0653
# [flaml.automl.logger: 01-28 05:47:53] {2282} INFO - iteration 81, current learner sgd
# [flaml.automl.logger: 01-28 05:47:53] {2466} INFO -  at 15.7s,	estimator sgd's best error=0.1641,	best estimator xgboost's best error=0.0653
# [flaml.automl.logger: 01-28 05:47
,	estimator xgb_limitdepth's best error=0.0707,	best estimator xgboost's best error=0.0628
# [flaml.automl.logger: 01-28 05:48:06] {2282} INFO - iteration 145, current learner xgb_limitdepth
# [flaml.automl.logger: 01-28 05:48:06] {2466} INFO -  at 28.8s,	estimator xgb_limitdepth's best error=0.0707,	best estimator xgboost's best error=0.0628
# [flaml.automl.logger: 01-28 05:48:06] {2282} INFO - iteration 146, current learner extra_tree
# [flaml.automl.logger: 01-28 05:48:06] {2466} INFO -  at 29.0s,	estimator extra_tree's best error=0.1020,	best estimator xgboost's best error=0.0628
# [flaml.automl.logger: 01-28 05:48:06] {2282} INFO - iteration 147, current learner xgboost
# [flaml.automl.logger: 01-28 05:48:06] {2466} INFO -  at 29.2s,	estimator xgboost's best error=0.0628,	best estimator xgboost's best error=0.0628
# [flaml.automl.logger: 01-28 05:48:06] {2282} INFO - iteration 148, current learner xgboost
# [flaml.automl.logger: 01-28 05:48:07] {2466} INFO -  at 29.6s,	estimator xgboost's best error=0.0628,	best estimator xgboost's best error=0.0628
# [flaml.automl.logger: 01-28 05:48:07] {2282} INFO - iteration 149, current learner xgboost
# [flaml.automl.logger: 01-28 05:48:07] {2466} INFO -  at 29.8s,	estimator xgboost's best error=0.0628,	best estimator xgboost's best error=0.0628
# [flaml.automl.logger: 01-28 05:48:07] {2282} INFO - iteration 150, current learner lrl1
# [flaml.automl.logger: 01-28 05:48:07] {2466} INFO -  at 30.0s,	estimator lrl1's best error=0.3791,	best estimator xgboost's best error=0.0628
# [flaml.automl.logger: 01-28 05:48:07] {803} INFO - logging best model xgboost
# [flaml.automl.logger: 01-28 05:48:08] {2724} INFO - retrain xgboost for 0.3s
# [flaml.automl.logger: 01-28 05:48:08] {2727} INFO - retrained model: XGBClassifier(base_score=None, booster=None, callbacks=[],
#               colsample_bylevel=0.7026718994656362, colsample_bynode=None,
#               colsample_bytree=0.9805095499780241, device=None,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, gamma=None,
#               grow_policy='lossguide', importance_type=None,
#               interaction_constraints=None, learning_rate=0.3540734056105625,
#               max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=0, max_leaves=15,
#               min_child_weight=0.089552847121642, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=39,
#               n_jobs=-1, num_parallel_tree=None, random_state=None, ...)
# [flaml.automl.logger: 01-28 05:48:08] {2729} INFO - Best MLflow run name: flaml_run_v1_child_120
# [flaml.automl.logger: 01-28 05:48:08] {2730} INFO - Best MLflow run id: di9b-bghm-nu7h-pulc
# [flaml.automl.logger: 01-28 05:48:15] {2009} INFO - fit succeeded
# [flaml.automl.logger: 01-28 05:48:15] {2010} INFO - Time taken to find the best model: 23.50335144996643
# Best ML leaner: xgboost
# Best loss: 0.06277234483015182
# Run saved to MLflow!

# %%
print(X_train.head(1))
# Out:
#             V1        V2        V3        V4        V5        V6        V7  \
# 3021  1.721567 -0.278398 -0.374122  1.620882 -0.643373 -0.399292 -0.529103
#
#             V8        V9       V10  ...       V20       V21       V22  \
# 3021  0.028126  1.068808 -0.411499  ... -0.002246  0.054291  0.135393
#
#            V23       V24      V25       V26       V27       V28  Amount
# 3021  0.177179 -0.151525 -0.38247 -0.763582  0.079404  0.024146  103.71
#
# [1 rows x 29 columns]

# %% [markdown]
# ## Evaluation
#
# We can inspect the best model found and evaluate it on our test set.

# %%
# Retrieve the best model found
print('Best ML learner:', automl.best_estimator)
print('Best hyperparmeter config:', automl.best_config)
print('Best Average Precision on validation data: {0:.4g}'.format(1-automl.best_loss))

# Evaluate on the test set
y_pred_proba = automl.predict_proba(X_test)[:, 1] # Get probabilities for class 1

# Calculate Average Precision Score manually
ap_score = average_precision_score(y_test, y_pred_proba)
print(f"Test Set Average Precision Score: {ap_score:.4f}")

# %% [markdown]
# ## Save Model
#
# We can save the optimized AutoML object using pickle.

# %%
with open('flaml_fraud_model.pkl', 'wb') as f:
    pickle.dump(automl, f)

print("Model saved to flaml_fraud_model.pkl")

# %% [markdown]
# ***If this documentation includes code, including but not limited to, code examples, Cloudera makes this available to you under the terms of the Apache License, Version 2.0, including any required notices. A copy of the Apache License Version 2.0 can be found [here](https://opensource.org/licenses/Apache-2.0).***
